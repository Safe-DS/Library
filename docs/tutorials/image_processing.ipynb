# %% [markdown]
# # Image Processing
#
# This tutorial explains how images can be handled and transformed with the `Image` class.
#
# **Important note:** All operations on a `Image` return a new `Image`. The original `Image` will not be changed.

# %% [markdown]
# 1. Load your data into an `Image`:

# %%
from safeds.data.image.containers import Image

boy = Image.from_png_file("data/boy.png")
boy

# %% [markdown]
# 2. Resize the `Image` to be have the width 300 and height 250:

# %%
boy.resize(200,170)

# %% [markdown]
# 3. Convert the `Image` to a grayscale:

# %%
boy.convert_to_grayscale()

# %% [markdown]
# 4. Crop the `Image` to be 200x200 with the top-left corner being at (250, 130):

# %%
boy.crop(250, 130, 200, 200)

# %% [markdown]
# 5. Flip the `Image` horizontally (or vertically):

# %%
boy.flip_horizontally()

# %% [markdown]
# 6. Adjust the brightness of the `Image`.
#
# By giving a factor below 1 the result will be a darker `Image`, a factor above 1 will return a brighter `Image`

# %%
 boy.adjust_brightness(1.5)

# %% [markdown]
# 7. Adjust the contrast of the `Image`.
#
# By giving a factor below 1 will decrease the contrast of the `Image`, a factor above 1 will increase the contrast `Image`

# %%
boy.adjust_contrast(1.5)

# %% [markdown]
# 8. Blur the `Image`:
#
# The higher the radius the blurrier the `Image` gets.
# The radius defines the amount of pixels united in each direction.

# %%
boy.blur(5)

# %% [markdown]
# 9. Sharpen the `Image`:
#
# The factor defines the sharpness of the returned `Image`.

# %%
boy.sharpen(5)

# %% [markdown]
# 10. Invert the colors of the `Image`:

# %%
boy.invert_colors()

# %% [markdown]
# 11. Rotate the `Image` to the right (or the left):

# %%
boy.rotate_right()

# %% [markdown]
# 12. Convert the `Image` to a grayscale and highlight the edges:

# %%
boy.find_edges()
